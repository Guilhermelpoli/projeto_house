# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from pycaret.regression import *
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset

# %%
# downloading the dataset
train = pd.read_csv('data/train.csv')
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# downloading the dataset
test = pd.read_csv('data/test.csv')

# %% [markdown]
# # Displaying all columns

# %%
#to see all dataset columns
pd.options.display.max_columns = None

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### The first thing first we checked was all NaN data.

# %%
#Heatmap of nulls
fig, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(train.isnull(), cbar=False);

# %%
# see all dataset information
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# see the number of nulls in each column
train.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# ### Checking the dtypes

# %%
#checking the amount of each dtype
train.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
#checking all object columns
train.dtypes[train.dtypes == 'object']
# Out:
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# ...

# %% [markdown]
# ### Checking with numeric columns

# %%
# selecting numeric columns in a new variable

train_num = train.select_dtypes(include = ['float', 'int'])

# %%
# histogram of numeric columns

train_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'MSSubClass'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>,
#         <AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'OverallQual'}>,
#         <AxesSubplot:title={'center':'OverallCond'}>],
#        [<AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'YearRemodAdd'}>,
#         <AxesSubplot:title={'center':'MasVnrArea'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF1'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF2'}>,
#         <AxesSubplot:title={'center':'BsmtUnfSF'}>],
#        [<AxesSubplot:title={'center':'TotalBsmtSF'}>,
#         <AxesSubplot:title={'center':'1stFlrSF'}>,
#         <AxesSubplot:title={'center':'2ndFlrSF'}>,
#         <AxesSubplot:title={'center':'LowQualFinSF'}>,
#         <AxesSubplot:title={'center':'GrLivArea'}>,
#         <AxesSubplot:title={'center':'BsmtFullBath'}>],
# ...

# %%
# making the correlation of numerical columns with the Sale Price column
train_num_corr = train_num.corr()['SalePrice'][:-1] 
golden_features_list = train_num_corr[abs(train_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with SalePrice:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 10 strongly correlated values with SalePrice:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %%
# checking for outliers
k=1
plt.figure(figsize=(40,30))
for col in ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold', 'SalePrice']:
    plt.subplot(10,4,k)
    sns.boxplot(x=train[col])
    k+=1
plt.show()

# %% [markdown]
# # Data cleaning

# %%
# exchanging objects for numeric values and transforming into float
train = train.replace({"MSZoning":{"C (all)": "0","FV":"1","RH":"2","RL":"3","RM":"4"},"Street":{"Pave": "0","Grvl":"1"},"Alley":{"Grvl":"0","Pave":"1"},"LotShape":{"Reg":"0","IR1":"1","IR2":"2","IR3":"3"},"LandContour":{"Lvl":"0","Bnk":"1","HLS":"2","Low":"3"},"Utilities": {"AllPub":"0","NoSeWa":"1"},"LotConfig":{"Inside":"0","Corner":"1","CulDSac":"2","CulDSac":"3","FR2":"4","FR3":"5"},"LandSlope":{"Gtl":"0","Mod":"1","Sev":"2"},"LotConfig":{"Inside":"0","Corner":"1","CulDSac":"2","CulDSac":"3","FR2":"4","FR3":"5"},"Neighborhood":{"Blmngtn":"0","Blueste":"1","BrDale":"2","BrkSide":"3","ClearCr":"4","CollgCr":"5","Crawfor":"6","Edwards":"7","Gilbert":"8","IDOTRR":"9","MeadowV":"10","Mitchel":"11","NAmes":"12","NoRidge":"13","NPkVill":"14","NridgHt":"15","NWAmes":"16","OldTown":"17","SWISU":"18","Sawyer":"19","SawyerW":"20","Somerst":"21","StoneBr":"22","Timber":"23","Veenker":"24"},"Condition1":{"Artery":"0","Feedr":"1","Norm":"2","RRNn":"3","RRAn":"4","PosN":"5","PosA":"6","RRNe":"7","RRAe":"8"},"Condition2":{"Artery":"0","Feedr":"1","Norm":"2","RRNn":"3","RRAn":"4","PosN":"5","PosA":"6","RRNe":"7","RRAe":"8"},"BldgType":{"1Fam": "0","2fmCon":"1","Duplex":"2","TwnhsE":"3","Twnhs":"4"},"HouseStyle":{"1Story":"0","1.5Fin":"1","1.5Unf":"2","2Story":"3","2.5Fin":"4","2.5Unf":"5","SFoyer":"6","SLvl":"7"},"RoofStyle":{"Flat":"0","Gable":"1","Gambrel":"2","Hip":"3","Mansard":"4","Shed":"5"},"RoofMatl":{"ClyTile":"0","CompShg":"1","Membran":"2","Metal":"3","Roll":"4","Tar&Grv":"5","WdShake":"6","WdShngl":"7"},"Exterior1st":{"AsbShng":"0","AsphShn":"1","BrkComm":"2","BrkFace":"3","CBlock":"4","CemntBd":"5","HdBoard":"6","ImStucc":"7","MetalSd":"8","Plywood":"9","Stone":"10","Stucco":"11","VinylSd":"12","Wd Sdng":"13","WdShing":"14"},"Exterior2nd":{"AsbShng":"0","AsphShn":"1","Brk Cmn":"2","BrkFace":"3","CBlock":"4","CmentBd":"5","HdBoard":"6","ImStucc":"7","MetalSd":"8","Other":"9","Plywood":"10","Stone":"11","Stucco":"12","VinylSd":"13","Wd Sdng":"14","Wd Shng":"15"},"MasVnrType":{"BrkCmn": "0","BrkFace":"1","None":"2","Stone":"3"},"ExterQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3"},"ExterCond":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"Foundation":{"BrkTil": "0","CBlock":"1","PConc":"2","Slab":"3","Stone":"4","Wood":"5"},"BsmtQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3"},"BsmtCond":{"Gd":"1","TA":"2","Fa":"3","Po":"4"},"BsmtExposure":{"Gd":"0","Av":"1","Mn":"2","No":"3"},"BsmtFinType1":{"GLQ": "0","ALQ":"1","BLQ":"2","Rec":"3","LwQ":"4","Unf":"5"},"BsmtFinType2":{"GLQ": "0","ALQ":"1","BLQ":"2","Rec":"3","LwQ":"4","Unf":"5"},"Heating":{"Floor": "0","GasA":"1","GasW":"2","Grav":"3","OthW":"4","Wall":"5"},"HeatingQC":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"CentralAir":{"Y": "0","N":"1"},"Electrical":{"SBrkr": "0","FuseA":"1","FuseF":"2","FuseP":"3","Mix":"4"},"KitchenQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3"},"Functional":{"Typ": "0","Min1":"1","Min2":"2","Mod":"3","Maj1":"4","Maj2":"5","Sev":"6"},"FireplaceQu":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"GarageType":{"2Types": "0","Attchd":"1","Basment":"2","BuiltIn":"3","CarPort":"4","Detchd":"5"},"GarageFinish":{"Fin": "0","RFn":"1","Unf":"2"},"GarageQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"GarageCond":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"PavedDrive":{"Y": "0","P":"1","N":"2"},"Fence":{"GdPrv": "0","MnPrv":"1","GdWo":"2","MnWw":"3"},"PoolQC":{"Ex": "0","Gd":"1","Fa":"2"},"MiscFeature":{"Gar2": "0","Othr":"1","Shed":"2","TenC":"3"},"SaleType":{"WD":"0","CWD":"1","New":"2","COD":"3","Con":"4","ConLw":"5","ConLI":"6","ConLD":"7","Oth":"8"},"SaleCondition":{"Normal":"0","Abnorml":"1","AdjLand":"2","Alloca":"3","Family":"4","Partial":"5"}}).astype('float')

# exchanging the null values of the columns above as seen in the documentation for numeric values and transforming into float
train.fillna({"Alley":"2","BsmtQual":"4","BsmtCond":"5","BsmtExposure":"4","BsmtFinType1":"6","BsmtFinType2":"6","FireplaceQu":"5","GarageType":"6","GarageFinish":"3","GarageQual":"5","GarageCond":"5","PoolQC":"3","Fence":"4","MiscFeature":"4"}, inplace=True)

# %%
# exchanging objects for numeric values and transforming into float
test = test.replace({"MSZoning":{"C (all)": "0","FV":"1","RH":"2","RL":"3","RM":"4"},"Street":{"Pave": "0","Grvl":"1"},"Alley":{"Grvl":"0","Pave":"1"},"LotShape":{"Reg":"0","IR1":"1","IR2":"2","IR3":"3"},"LandContour":{"Lvl":"0","Bnk":"1","HLS":"2","Low":"3"},"Utilities": {"AllPub":"0","NoSeWa":"1"},"LotConfig":{"Inside":"0","Corner":"1","CulDSac":"2","CulDSac":"3","FR2":"4","FR3":"5"},"LandSlope":{"Gtl":"0","Mod":"1","Sev":"2"},"LotConfig":{"Inside":"0","Corner":"1","CulDSac":"2","CulDSac":"3","FR2":"4","FR3":"5"},"Neighborhood":{"Blmngtn":"0","Blueste":"1","BrDale":"2","BrkSide":"3","ClearCr":"4","CollgCr":"5","Crawfor":"6","Edwards":"7","Gilbert":"8","IDOTRR":"9","MeadowV":"10","Mitchel":"11","NAmes":"12","NoRidge":"13","NPkVill":"14","NridgHt":"15","NWAmes":"16","OldTown":"17","SWISU":"18","Sawyer":"19","SawyerW":"20","Somerst":"21","StoneBr":"22","Timber":"23","Veenker":"24"},"Condition1":{"Artery":"0","Feedr":"1","Norm":"2","RRNn":"3","RRAn":"4","PosN":"5","PosA":"6","RRNe":"7","RRAe":"8"},"Condition2":{"Artery":"0","Feedr":"1","Norm":"2","RRNn":"3","RRAn":"4","PosN":"5","PosA":"6","RRNe":"7","RRAe":"8"},"BldgType":{"1Fam": "0","2fmCon":"1","Duplex":"2","TwnhsE":"3","Twnhs":"4"},"HouseStyle":{"1Story":"0","1.5Fin":"1","1.5Unf":"2","2Story":"3","2.5Fin":"4","2.5Unf":"5","SFoyer":"6","SLvl":"7"},"RoofStyle":{"Flat":"0","Gable":"1","Gambrel":"2","Hip":"3","Mansard":"4","Shed":"5"},"RoofMatl":{"ClyTile":"0","CompShg":"1","Membran":"2","Metal":"3","Roll":"4","Tar&Grv":"5","WdShake":"6","WdShngl":"7"},"Exterior1st":{"AsbShng":"0","AsphShn":"1","BrkComm":"2","BrkFace":"3","CBlock":"4","CemntBd":"5","HdBoard":"6","ImStucc":"7","MetalSd":"8","Plywood":"9","Stone":"10","Stucco":"11","VinylSd":"12","Wd Sdng":"13","WdShing":"14"},"Exterior2nd":{"AsbShng":"0","AsphShn":"1","Brk Cmn":"2","BrkFace":"3","CBlock":"4","CmentBd":"5","HdBoard":"6","ImStucc":"7","MetalSd":"8","Other":"9","Plywood":"10","Stone":"11","Stucco":"12","VinylSd":"13","Wd Sdng":"14","Wd Shng":"15"},"MasVnrType":{"BrkCmn": "0","BrkFace":"1","None":"2","Stone":"3"},"ExterQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3"},"ExterCond":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"Foundation":{"BrkTil": "0","CBlock":"1","PConc":"2","Slab":"3","Stone":"4","Wood":"5"},"BsmtQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3"},"BsmtCond":{"Gd":"1","TA":"2","Fa":"3","Po":"4"},"BsmtExposure":{"Gd":"0","Av":"1","Mn":"2","No":"3"},"BsmtFinType1":{"GLQ": "0","ALQ":"1","BLQ":"2","Rec":"3","LwQ":"4","Unf":"5"},"BsmtFinType2":{"GLQ": "0","ALQ":"1","BLQ":"2","Rec":"3","LwQ":"4","Unf":"5"},"Heating":{"Floor": "0","GasA":"1","GasW":"2","Grav":"3","OthW":"4","Wall":"5"},"HeatingQC":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"CentralAir":{"Y": "0","N":"1"},"Electrical":{"SBrkr": "0","FuseA":"1","FuseF":"2","FuseP":"3","Mix":"4"},"KitchenQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3"},"Functional":{"Typ": "0","Min1":"1","Min2":"2","Mod":"3","Maj1":"4","Maj2":"5","Sev":"6"},"FireplaceQu":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"GarageType":{"2Types": "0","Attchd":"1","Basment":"2","BuiltIn":"3","CarPort":"4","Detchd":"5"},"GarageFinish":{"Fin": "0","RFn":"1","Unf":"2"},"GarageQual":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"GarageCond":{"Ex": "0","Gd":"1","TA":"2","Fa":"3","Po":"4"},"PavedDrive":{"Y": "0","P":"1","N":"2"},"Fence":{"GdPrv": "0","MnPrv":"1","GdWo":"2","MnWw":"3"},"PoolQC":{"Ex": "0","Gd":"1","Fa":"2"},"MiscFeature":{"Gar2": "0","Othr":"1","Shed":"2","TenC":"3"},"SaleType":{"WD":"0","CWD":"1","New":"2","COD":"3","Con":"4","ConLw":"5","ConLI":"6","ConLD":"7","Oth":"8"},"SaleCondition":{"Normal":"0","Abnorml":"1","AdjLand":"2","Alloca":"3","Family":"4","Partial":"5"}}).astype('float')

# exchanging the null values of the columns above as seen in the documentation for numeric values and transforming into float
test.fillna({"Alley":"2","BsmtQual":"4","BsmtCond":"5","BsmtExposure":"4","BsmtFinType1":"6","BsmtFinType2":"6","FireplaceQu":"5","GarageType":"6","GarageFinish":"3","GarageQual":"5","GarageCond":"5","PoolQC":"3","Fence":"4","MiscFeature":"4"}, inplace=True)

# %%
#exchanging the remaining null values of the dataset by the average of the values and the most frequent ones.

train[['LotFrontage']] = pd.DataFrame(SimpleImputer(strategy='mean').fit_transform(train[['LotFrontage']]))
train[['MasVnrArea']] = pd.DataFrame(SimpleImputer(strategy='mean').fit_transform(train[['MasVnrArea']]))
train[['MasVnrType']] = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(train[['MasVnrType']]))
train[['Electrical']] = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(train[['Electrical']]))
train[['GarageYrBlt']] = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(train[['GarageYrBlt']]))

# %%
# exchanging the remaining null values of the dataset by the average of the values and the most frequent ones.
test[['LotFrontage']] = pd.DataFrame(SimpleImputer(strategy='mean').fit_transform(train[['LotFrontage']]))
test[['MasVnrArea']] = pd.DataFrame(SimpleImputer(strategy='mean').fit_transform(train[['MasVnrArea']]))
test[['MasVnrType']] = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(train[['MasVnrType']]))
test[['Electrical']] = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(train[['Electrical']]))
test[['GarageYrBlt']] = pd.DataFrame(SimpleImputer(strategy='most_frequent').fit_transform(train[['GarageYrBlt']]))

# %%
# a function to remove outliers
def remove_outlier(column):
    '''Função para remover os outlier, usando o IQR que 
    é a subtração do p75 - p25'''
    p25 = column.describe()[4]
    p75 = column.describe()[6]
    IQR = p75 - p25
    ul = p75 + 1.5*IQR
    ll = p25 - 1.5*IQR
    column.mask(column>ul,ul,inplace=True)
    column.mask(column<ll,ll,inplace=True)

# %%
# removing outliers with the above function     
for col in train:
    if col != 'YearRemodAdd' and col != 'BsmtFinSF2' and col != 'LowQualFinSF' and col != 'BsmtHalfBath' and col != 'KitchenAbvGr' and col != 'EnclosedPorch'and col != '3SsnPorch' and col != 'ScreenPorch'and col != 'PoolArea'and col !='MiscVal'and col != 'MSZoning' and col != 'Street' and col != 'Alley' and col != 'LotShape' and col != 'LandContour' and col != 'Utilities' and col != 'LotConfig' and col != 'LandSlope' and col != 'Neighborhood' and col !=  'Condition1' and col != 'Condition2' and col != 'BldgType' and col != 'HouseStyle' and col != 'RoofStyle' and col != 'RoofMatl' and col != 'Exterior1st' and col != 'Exterior2nd' and col != 'MasVnrType' and col != 'ExterQual' and col != 'ExterCond' and col !=  'Foundation' and col != 'BsmtQual' and col != 'BsmtCond' and col != 'BsmtExposure' and col != 'BsmtFinType1' and col != 'BsmtFinType2' and col != 'Heating' and col != 'HeatingQC' and col != 'CentralAir' and col != 'Electrical' and col != 'KitchenQual' and col != 'Functional' and col != 'FireplaceQu' and col != 'GarageType' and col != 'GarageFinish' and col != 'GarageQual' and col != 'GarageCond' and  col != 'PavedDrive' and col != 'PoolQC' and col != 'Fence' and col != 'MiscFeature' and col != 'SaleType' and col != 'SaleCondition':
        remove_outlier(train[col])

# %%
# removing outliers with the above function      
for col in test:
    if col != 'YearRemodAdd' and col != 'BsmtFinSF2' and col != 'LowQualFinSF' and col != 'BsmtHalfBath' and col != 'KitchenAbvGr' and col != 'EnclosedPorch'and col != '3SsnPorch' and col != 'ScreenPorch'and col != 'PoolArea'and col !='MiscVal'and col != 'MSZoning' and col != 'Street' and col != 'Alley' and col != 'LotShape' and col != 'LandContour' and col != 'Utilities' and col != 'LotConfig' and col != 'LandSlope' and col != 'Neighborhood' and col !=  'Condition1' and col != 'Condition2' and col != 'BldgType' and col != 'HouseStyle' and col != 'RoofStyle' and col != 'RoofMatl' and col != 'Exterior1st' and col != 'Exterior2nd' and col != 'MasVnrType' and col != 'ExterQual' and col != 'ExterCond' and col !=  'Foundation' and col != 'BsmtQual' and col != 'BsmtCond' and col != 'BsmtExposure' and col != 'BsmtFinType1' and col != 'BsmtFinType2' and col != 'Heating' and col != 'HeatingQC' and col != 'CentralAir' and col != 'Electrical' and col != 'KitchenQual' and col != 'Functional' and col != 'FireplaceQu' and col != 'GarageType' and col != 'GarageFinish' and col != 'GarageQual' and col != 'GarageCond' and  col != 'PavedDrive' and col != 'PoolQC' and col != 'Fence' and col != 'MiscFeature' and col != 'SaleType' and col != 'SaleCondition':
        remove_outlier(test[col])

# %% [markdown]
# # Setting up Environment in PyCaret

# %%
data_train,data_test = train_test_split(train, test_size = 0.1, random_state = 23)

# %% [markdown]
# ### setup the pipeline

# %%
# feature_slection = seleciona as colunas mais importantes para o modelo
# transformation = transforma as variaveis explicativas para ficar com o distribuição normal
regression = setup(data = data_train, target = 'SalePrice', session_id=42,fold = 3,
                      feature_selection=True,
                       transformation= True)
# Out:
# <style type="text/css">
# #T_f41f3_row29_col1, #T_f41f3_row42_col1, #T_f41f3_row50_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f41f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f41f3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f41f3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f41f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f41f3_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f41f3_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f41f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f41f3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f41f3_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Comparing All Models

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_c110b th {
#   text-align: left;
# }
# ...

# %%
print(best_model)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# ### Tune a Model

# %%
tuned_best = tune_model(best_model, n_iter=100,optimize='RMSE', choose_better=True)
# Out:
# <style type="text/css">
# #T_85244_row3_col0, #T_85244_row3_col1, #T_85244_row3_col2, #T_85244_row3_col3, #T_85244_row3_col4, #T_85244_row3_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_85244">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85244_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_85244_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_85244_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_85244_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_85244_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_85244_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(tuned_best)

# %% [markdown]
# ### Plot a Model

# %%
plot_model(tuned_best, plot = 'error')

# %%
plot_model(tuned_best, plot='feature_all')

# %%
evaluate_model(tuned_best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Predict on Test / Hold-out Sample

# %%
predict_model(tuned_best);
# Out:
# <style type="text/css">
# </style>
# <table id="T_9830f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9830f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9830f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9830f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9830f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9830f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9830f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9830f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9830f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9830f_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9830f_row0_col1" class="data row0 col1" >15899.7854</td>
# ...

# %% [markdown]
# ### Finalize Model for Deployment

# %%
final_best = finalize_model(tuned_best)

# %%
print(final_best)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.05, loss='ls', max_depth=6,
#                           max_features='sqrt', max_leaf_nodes=None,
#                           min_impurity_decrease=0.3, min_impurity_split=None,
#                           min_samples_leaf=4, min_samples_split=10,
#                           min_weight_fraction_leaf=0.0, n_estimators=270,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=0.7, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
predict_model(final_best);
# Out:
# <style type="text/css">
# </style>
# <table id="T_78169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78169_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_78169_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_78169_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_78169_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_78169_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_78169_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_78169_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78169_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_78169_row0_col1" class="data row0 col1" >5292.5930</td>
# ...

# %% [markdown]
# ### Predict on Unseen Data

# %%
unseen_predictions = predict_model(final_best, data=test)
unseen_predictions.head()
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street Alley  LotShape  \
# 0  1461.0        20.0       2.0         65.0  11622.0     0.0     2       0.0
# 1  1462.0        20.0       3.0         80.0  14267.0     0.0     2       1.0
# 2  1463.0        60.0       3.0         68.0  13830.0     0.0     2       1.0
# 3  1464.0        60.0       3.0         60.0   9978.0     0.0     2       1.0
# 4  1465.0       120.0       3.0         84.0   5005.0     0.0     2       1.0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0          0.0        0.0  ...       0.0       3    1.0            4      0.0
# 1          0.0        0.0  ...       0.0       3      4          0.0  12500.0
# 2          0.0        0.0  ...       0.0       3    1.0            4      0.0
# 3          0.0        0.0  ...       0.0       3      4            4      0.0
# 4          2.0        0.0  ...       0.0       3      4            4      0.0
#
# ...

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions.Label, unseen_predictions.Label, 'R2')
# Out:
# 1.0

# %% [markdown]
# # Saving the Model

# %%
save_model(best_model,'Final best model 29julho2022')
